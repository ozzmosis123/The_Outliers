# %%
import pandas as pd

# %%
AirBnB_data = pd.read_csv("listings.csv",low_memory=False)
crime_data = pd.read_csv("crime_counts_2019.csv")

# %%
merged_data = pd.merge(AirBnB_data, crime_data, how="left", on="city")
merged_data
# Out:
#              id                            listing_url       scrape_id  \
# 0           109       https://www.airbnb.com/rooms/109  20191205175409
# 1           344       https://www.airbnb.com/rooms/344  20191205175409
# 2          2708      https://www.airbnb.com/rooms/2708  20191205175409
# 3          2732      https://www.airbnb.com/rooms/2732  20191205175409
# 4          2864      https://www.airbnb.com/rooms/2864  20191205175409
# ...         ...                                    ...             ...
# 40120  40599772  https://www.airbnb.com/rooms/40599772  20191205175409
# 40121  40599853  https://www.airbnb.com/rooms/40599853  20191205175409
# 40122  40601503  https://www.airbnb.com/rooms/40601503  20191205175409
# 40123  40601789  https://www.airbnb.com/rooms/40601789  20191205175409
# 40124  40603848  https://www.airbnb.com/rooms/40603848  20191205175409
#
#       last_scraped                                               name  \
# 0       2019-12-06  Amazing bright elegant condo park front *UPGRA...
# 1       2019-12-06                  Family perfect;Pool;Near Studios!
# 2       2019-12-06  Mirrored Mini-Suite with Fireplace - W. Hollywood
# 3       2019-12-06                              Zen Life at the Beach
# 4       2019-12-07  *Upscale Professional Home with Beautiful Studio*
# ...            ...                                                ...
# 40120   2019-12-06  Bright Spacious two bedroom apartment by the b...
# 40121   2019-12-06                              Studio near the beach
# 40122   2019-12-06  Cozy Studio maximum 4 person near many attract...
# 40123   2019-12-06                         Hollywood Classic Bungalow
# 40124   2019-12-06    USC walking distance mice apartment big sofabed
#
#                                                  summary  \
# 0      *** Unit upgraded with new bamboo flooring, br...
# 1      This home is perfect for families; aspiring ch...
# 2      Our best memory foam pillows you'll ever sleep...
# 3                                                    NaN
# 4      Centrally located.... Furnished with 42 inch S...
# ...                                                  ...
# 40120  Brand new spacious apartment! this two bedroom...
# 40121  Beautiful modern studio apartment located in M...
# 40122                                                NaN
# 40123  Heart of Hollywood Bungalow central to the bes...
# 40124                                                NaN
#
#                                                    space  \
# 0      *** Unit upgraded with new bamboo flooring, br...
# 1      Cheerful & comfortable; near studios, amusemen...
# 2      Flickering fireplace.  Blendtec® Designer 625 ...
# 3      This is a three story townhouse with the follo...
# 4      The space is furnished with Thomasville furnit...
# ...                                                  ...
# 40120  the apartment is more than 1200sqft, has two b...
# 40121  Full kitchen equipped for all your cooking nee...
# 40122                                                NaN
# 40123  Heart of Hollywood Bungalow central to the bes...
# 40124                                                NaN
#
#                                              description experiences_offered  \
# 0      *** Unit upgraded with new bamboo flooring, br...                none
# 1      This home is perfect for families; aspiring ch...                none
# 2      Our best memory foam pillows you'll ever sleep...                none
# 3      This is a three story townhouse with the follo...                none
# 4      Centrally located.... Furnished with 42 inch S...                none
# ...                                                  ...                 ...
# 40120  Brand new spacious apartment! this two bedroom...                none
# 40121  Beautiful modern studio apartment located in M...                none
# 40122                                                NaN                none
# 40123  Heart of Hollywood Bungalow central to the bes...                none
# 40124                                                NaN                none
#
#                                    neighborhood_overview  ...  \
# 0                                                    NaN  ...
# 1      Quiet-yet-close to all the fun in LA! Hollywoo...  ...
# 2      We are minutes away from the Mentor Language I...  ...
# 3                                                    NaN  ...
# 4      What makes the neighborhood unique is that the...  ...
# ...                                                  ...  ...
# 40120                                                NaN  ...
# 40121  Venice beach, Venice canals, the Santa Monica ...  ...
# 40122                                                NaN  ...
# 40123  There is an amazing pilates studio right in th...  ...
# 40124                                                NaN  ...
#
#                cancellation_policy require_guest_profile_picture  \
# 0      strict_14_with_grace_period                             t
# 1                         flexible                             f
# 2      strict_14_with_grace_period                             f
# 3      strict_14_with_grace_period                             f
# 4      strict_14_with_grace_period                             f
# ...                            ...                           ...
# 40120  strict_14_with_grace_period                             f
# 40121                     moderate                             f
# 40122                     flexible                             f
# 40123                     moderate                             f
# 40124                     flexible                             f
#
#       require_guest_phone_verification calculated_host_listings_count  \
# 0                                    f                              1
# 1                                    f                              1
# 2                                    f                              2
# 3                                    f                              2
# 4                                    f                              1
# ...                                ...                            ...
# 40120                                f                              1
# 40121                                f                              2
# 40122                                f                              3
# 40123                                f                              3
# 40124                                f                              4
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               1
# 2                                               0
# 3                                               1
# 4                                               1
# ...                                           ...
# 40120                                           1
# 40121                                           2
# 40122                                           3
# 40123                                           3
# 40124                                           0
#
#        calculated_host_listings_count_private_rooms  \
# 0                                                 0
# 1                                                 0
# 2                                                 2
# 3                                                 1
# 4                                                 0
# ...                                             ...
# 40120                                             0
# 40121                                             0
# 40122                                             0
# 40123                                             0
# 40124                                             1
#
#        calculated_host_listings_count_shared_rooms reviews_per_month    crime  \
# 0                                                0              0.02  10911.0
# 1                                                0              0.19   8775.0
# 2                                                0              0.33  47879.0
# 3                                                0              0.19   7166.0
# 4                                                0               NaN      NaN
# ...                                            ...               ...      ...
# 40120                                            0               NaN      NaN
# 40121                                            0               NaN      NaN
# 40122                                            0               NaN      NaN
# 40123                                            0               NaN  47879.0
# 40124                                            3               NaN  47879.0
#
#          year
# 0      2019.0
# 1      2019.0
# 2      2019.0
# 3      2019.0
# 4         NaN
# ...       ...
# 40120     NaN
# 40121     NaN
# 40122     NaN
# 40123  2019.0
# 40124  2019.0
#
# [40125 rows x 108 columns]

# %%
#merged_data.to_csv("merged_data.csv")

# %%
merged_data=merged_data[['id','host_id','host_response_time','host_response_rate','host_is_superhost','host_listings_count','street','neighbourhood','neighbourhood_cleansed','neighbourhood_group_cleansed','city','state','zipcode','market','smart_location','country_code','country','latitude','longitude','property_type','room_type','accommodates','bathrooms','bedrooms','beds','square_feet','price','weekly_price','monthly_price','security_deposit','cleaning_fee','guests_included','extra_people','minimum_nights','maximum_nights','calendar_updated','availability_30','availability_60','availability_90','availability_365','number_of_reviews','review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_location','reviews_per_month','crime','year']]
merged_data
# Out:
#              id    host_id  host_response_time host_response_rate  \
# 0           109        521                 NaN                NaN
# 1           344        767  within a few hours               100%
# 2          2708       3008  within a few hours               100%
# 3          2732       3041  within a few hours               100%
# 4          2864       3207                 NaN                NaN
# ...         ...        ...                 ...                ...
# 40120  40599772  314561523                 NaN                NaN
# 40121  40599853   21414814                 NaN                NaN
# 40122  40601503  301336206  a few days or more                40%
# 40123  40601789     322037      within an hour               100%
# 40124  40603848  253766997  within a few hours                88%
#
#       host_is_superhost  host_listings_count  \
# 0                     f                  1.0
# 1                     f                  1.0
# 2                     t                  2.0
# 3                     t                  2.0
# 4                     f                  1.0
# ...                 ...                  ...
# 40120                 f                  0.0
# 40121                 f                  0.0
# 40122                 f                  6.0
# 40123                 f                  3.0
# 40124                 f                  5.0
#
#                                   street   neighbourhood  \
# 0         Culver City, CA, United States     Culver City
# 1             Burbank, CA, United States         Burbank
# 2         Los Angeles, CA, United States       Hollywood
# 3        Santa Monica, CA, United States    Santa Monica
# 4          Bellflower, CA, United States      Bellflower
# ...                                  ...             ...
# 40120  Marina del Rey, CA, United States  Marina Del Rey
# 40121  Marina del Rey, CA, United States  Marina Del Rey
# 40122     Temple City, CA, United States     Temple City
# 40123     Los Angeles, CA, United States       Hollywood
# 40124     Los Angeles, CA, United States        South LA
#
#       neighbourhood_cleansed neighbourhood_group_cleansed  ...  \
# 0                Culver City                 Other Cities  ...
# 1                    Burbank                 Other Cities  ...
# 2                  Hollywood          City of Los Angeles  ...
# 3               Santa Monica                 Other Cities  ...
# 4                 Bellflower                 Other Cities  ...
# ...                      ...                          ...  ...
# 40120         Marina del Rey         Unincorporated Areas  ...
# 40121         Marina del Rey         Unincorporated Areas  ...
# 40122            Temple City                 Other Cities  ...
# 40123              Hollywood          City of Los Angeles  ...
# 40124        University Park          City of Los Angeles  ...
#
#       availability_365 number_of_reviews review_scores_rating  \
# 0                  248                 2                 80.0
# 1                   62                 8                 97.0
# 2                  252                22                 98.0
# 3                  344                20                 94.0
# 4                    0                 0                  NaN
# ...                ...               ...                  ...
# 40120              365                 0                  NaN
# 40121               18                 0                  NaN
# 40122               57                 0                  NaN
# 40123              178                 0                  NaN
# 40124              365                 0                  NaN
#
#       review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                       10.0                      10.0                   6.0
# 1                       10.0                      10.0                  10.0
# 2                       10.0                      10.0                  10.0
# 3                        9.0                       9.0                   9.0
# 4                        NaN                       NaN                   NaN
# ...                      ...                       ...                   ...
# 40120                    NaN                       NaN                   NaN
# 40121                    NaN                       NaN                   NaN
# 40122                    NaN                       NaN                   NaN
# 40123                    NaN                       NaN                   NaN
# 40124                    NaN                       NaN                   NaN
#
#       review_scores_location  reviews_per_month    crime    year
# 0                       10.0               0.02  10911.0  2019.0
# 1                       10.0               0.19   8775.0  2019.0
# 2                       10.0               0.33  47879.0  2019.0
# 3                       10.0               0.19   7166.0  2019.0
# 4                        NaN                NaN      NaN     NaN
# ...                      ...                ...      ...     ...
# 40120                    NaN                NaN      NaN     NaN
# 40121                    NaN                NaN      NaN     NaN
# 40122                    NaN                NaN      NaN     NaN
# 40123                    NaN                NaN  47879.0  2019.0
# 40124                    NaN                NaN  47879.0  2019.0
#
# [40125 rows x 49 columns]

# %%
merged_data=merged_data.dropna(how='all',subset=['crime'])
merged_data
# Out:
#              id    host_id  host_response_time host_response_rate  \
# 0           109        521                 NaN                NaN
# 1           344        767  within a few hours               100%
# 2          2708       3008  within a few hours               100%
# 3          2732       3041  within a few hours               100%
# 5          5728       9171      within an hour               100%
# ...         ...        ...                 ...                ...
# 40114  40597150   96353404      within an hour               100%
# 40115  40597239  314575538                 NaN                NaN
# 40119  40599427    3289615                 NaN                NaN
# 40123  40601789     322037      within an hour               100%
# 40124  40603848  253766997  within a few hours                88%
#
#       host_is_superhost  host_listings_count                           street  \
# 0                     f                  1.0   Culver City, CA, United States
# 1                     f                  1.0       Burbank, CA, United States
# 2                     t                  2.0   Los Angeles, CA, United States
# 3                     t                  2.0  Santa Monica, CA, United States
# 5                     t                  8.0   Los Angeles, CA, United States
# ...                 ...                  ...                              ...
# 40114                 f                  2.0   Los Angeles, CA, United States
# 40115                 f                  1.0   Los Angeles, CA, United States
# 40119                 f                  1.0   Los Angeles, CA, United States
# 40123                 f                  3.0   Los Angeles, CA, United States
# 40124                 f                  5.0   Los Angeles, CA, United States
#
#           neighbourhood neighbourhood_cleansed neighbourhood_group_cleansed  \
# 0           Culver City            Culver City                 Other Cities
# 1               Burbank                Burbank                 Other Cities
# 2             Hollywood              Hollywood          City of Los Angeles
# 3          Santa Monica           Santa Monica                 Other Cities
# 5               Del Rey                Del Rey          City of Los Angeles
# ...                 ...                    ...                          ...
# 40114  West Los Angeles               Sawtelle          City of Los Angeles
# 40115            Reseda                 Reseda          City of Los Angeles
# 40119            Venice                 Venice          City of Los Angeles
# 40123         Hollywood              Hollywood          City of Los Angeles
# 40124          South LA        University Park          City of Los Angeles
#
#        ... availability_365 number_of_reviews review_scores_rating  \
# 0      ...              248                 2                 80.0
# 1      ...               62                 8                 97.0
# 2      ...              252                22                 98.0
# 3      ...              344                20                 94.0
# 5      ...              326               305                 96.0
# ...    ...              ...               ...                  ...
# 40114  ...              353                 0                  NaN
# 40115  ...              179                 0                  NaN
# 40119  ...              131                 0                  NaN
# 40123  ...              178                 0                  NaN
# 40124  ...              365                 0                  NaN
#
#       review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                       10.0                      10.0                   6.0
# 1                       10.0                      10.0                  10.0
# 2                       10.0                      10.0                  10.0
# 3                        9.0                       9.0                   9.0
# 5                       10.0                      10.0                  10.0
# ...                      ...                       ...                   ...
# 40114                    NaN                       NaN                   NaN
# 40115                    NaN                       NaN                   NaN
# 40119                    NaN                       NaN                   NaN
# 40123                    NaN                       NaN                   NaN
# 40124                    NaN                       NaN                   NaN
#
#       review_scores_location  reviews_per_month    crime    year
# 0                       10.0               0.02  10911.0  2019.0
# 1                       10.0               0.19   8775.0  2019.0
# 2                       10.0               0.33  47879.0  2019.0
# 3                       10.0               0.19   7166.0  2019.0
# 5                       10.0               2.41  47879.0  2019.0
# ...                      ...                ...      ...     ...
# 40114                    NaN                NaN  47879.0  2019.0
# 40115                    NaN                NaN  47879.0  2019.0
# 40119                    NaN                NaN  47879.0  2019.0
# 40123                    NaN                NaN  47879.0  2019.0
# 40124                    NaN                NaN  47879.0  2019.0
#
# [31375 rows x 49 columns]

# %%
merged_data.to_csv("LA_AirBnB_with_crime.csv",index=False)
