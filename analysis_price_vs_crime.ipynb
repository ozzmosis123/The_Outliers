# %% [markdown]
# ### Compare AirBnB price and Crime data to find if there is a significant correlation between them

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np

# %%
airbnb_data = pd.read_csv("cities_with_all_interests_crimes.csv")
airbnb_data
# Out:
#            id    host_id  host_response_time host_response_rate  \
# 0    27402246  171503602                   0                  0
# 1     5627346    9355137      within an hour               100%
# 2    39090938  299617303      within an hour               100%
# 3    20678163    4271811                   0                  0
# 4     5299075    3118435  within a few hours                93%
# ..        ...        ...                 ...                ...
# 995  21612110  157214926      within an hour                93%
# 996  34204446   48005494  within a few hours                99%
# 997  13492765   12808522      within an hour               100%
# 998  25484807   45784450      within an hour               100%
# 999  20771460   15452100      within an hour               100%
#
#     host_is_superhost  host_listings_count                           street  \
# 0                   f                  1.0   Los Angeles, CA, United States
# 1                   f                  2.0   Los Angeles, CA, United States
# 2                   f                  0.0   Los Angeles, CA, United States
# 3                   f                  2.0   Los Angeles, CA, United States
# 4                   f                  9.0  Santa Monica, CA, United States
# ..                ...                  ...                              ...
# 995                 f                  1.0    Long Beach, CA, United States
# 996                 t               1759.0   Los Angeles, CA, United States
# 997                 t                  2.0   Los Angeles, CA, United States
# 998                 f                  8.0   Los Angeles, CA, United States
# 999                 t                  1.0   Los Angeles, CA, United States
#
#      neighbourhood neighbourhood_cleansed neighbourhood_group_cleansed  ...  \
# 0        Echo Park              Echo Park          City of Los Angeles  ...
# 1    Cahuenga Pass        Hollywood Hills          City of Los Angeles  ...
# 2     Mid-Wilshire         East Hollywood          City of Los Angeles  ...
# 3        Mar Vista              Mar Vista          City of Los Angeles  ...
# 4     Santa Monica           Santa Monica                 Other Cities  ...
# ..             ...                    ...                          ...  ...
# 995     Long Beach             Long Beach                 Other Cities  ...
# 996       Downtown               Downtown          City of Los Angeles  ...
# 997   Mid-Wilshire              Larchmont          City of Los Angeles  ...
# 998   Mid-Wilshire             Pico-Union          City of Los Angeles  ...
# 999  Highland Park          Highland Park          City of Los Angeles  ...
#
#     review_scores_rating review_scores_accuracy  review_scores_cleanliness  \
# 0                  100.0                   10.0                       10.0
# 1                   98.0                   10.0                       10.0
# 2                   93.0                    9.0                        9.0
# 3                   95.0                   10.0                       10.0
# 4                   87.0                    9.0                        9.0
# ..                   ...                    ...                        ...
# 995                 90.0                    9.0                        9.0
# 996                100.0                   10.0                        8.0
# 997                 99.0                   10.0                       10.0
# 998                 92.0                   10.0                        9.0
# 999                 96.0                   10.0                       10.0
#
#     review_scores_checkin review_scores_location reviews_per_month    crime  \
# 0                    10.0                   10.0              0.19  47879.0
# 1                    10.0                   10.0              0.16  47879.0
# 2                    10.0                    9.0              1.70  47879.0
# 3                    10.0                   10.0              0.26  47879.0
# 4                    10.0                    9.0              0.97   7166.0
# ..                    ...                    ...               ...      ...
# 995                   9.0                    8.0              2.99    148.0
# 996                  10.0                   10.0              0.30  47879.0
# 997                  10.0                   10.0              5.90  47879.0
# 998                  10.0                    9.0              1.13  47879.0
# 999                  10.0                   10.0              1.14  47879.0
#
#        year  # point of interest crime counts
# 0    2019.0                 19.0       2740.0
# 1    2019.0                 20.0          0.0
# 2    2019.0                 19.0       2234.0
# 3    2019.0                  8.0          0.0
# 4    2019.0                 20.0          0.0
# ..      ...                  ...          ...
# 995  2019.0                 20.0          0.0
# 996  2019.0                 20.0      15717.0
# 997  2019.0                 16.0        226.0
# 998  2019.0                 20.0       6998.0
# 999  2019.0                  7.0          0.0
#
# [1000 rows x 51 columns]

# %%
# Create a function to create Linear Regression plots and scatter chart, and print the r-squared
def linear_regression_plot(x_values, y_values, x_label, y_label):
    (slope, intercept, rvalue, pvalue, stdrr) = linregress(x_values, y_values)
    regress_values = slope * x_values + intercept
    line_eq = "y = "+str(round(slope,2))+"x + "+str(round(intercept,2))
    print(f"The r-squared is: {rvalue}")
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.title(f"{y_label} vs. {x_label}")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.annotate(line_eq,(x_values.median()-2,y_values.min()+1),fontsize=15,color="red")
    #plt.show()

# %%
# compared price with crime counts
# the r-squared is low. there is no significant correlation between them
values_x = airbnb_data['price']
values_y = airbnb_data['crime counts']
label_x = "price"
label_y = "crime count"
linear_regression_plot(values_x, values_y, label_x, label_y)
plt.savefig("price_vs_crime.png")
plt.show()
# Out:
# The r-squared is: 0.03882833549308283
